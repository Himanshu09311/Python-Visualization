# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import lxml
import pandas as pd
pdhtml=pd.read_html("https://www.basketball-reference.com/leaders/franchise.html")

# %%
len(pdhtml)
# Out:
# 2

# %%
type(pdhtml)
# Out:
# list

# %%
pdhtml[0].head()
# Out:
#                Franchise   Lg     From       To  Yrs          Season  \
# 0          Atlanta Hawks  NBA  1949-50  2022-23   74  Season Leaders
# 1          Atlanta Hawks  NBA  1968-69  2022-23   55             NaN
# 2        St. Louis Hawks  NBA  1955-56  1967-68   13             NaN
# 3        Milwaukee Hawks  NBA  1951-52  1954-55    4             NaN
# 4  Tri-Cities Blackhawks  NBA  1949-50  1950-51    2             NaN
#
#            Career
# 0  Career Leaders
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
pdhtml[0].tail()
# Out:
#              Franchise   Lg     From       To  Yrs Season Career
# 80  Washington Bullets  NBA  1974-75  1996-97   23    NaN    NaN
# 81     Capital Bullets  NBA  1973-74  1973-74    1    NaN    NaN
# 82   Baltimore Bullets  NBA  1963-64  1972-73   10    NaN    NaN
# 83     Chicago Zephyrs  NBA  1962-63  1962-63    1    NaN    NaN
# 84     Chicago Packers  NBA  1961-62  1961-62    1    NaN    NaN

# %%
pdhtml[0].columns
# Out:
# Index(['Franchise', 'Lg', 'From', 'To', 'Yrs', 'Season', 'Career'], dtype='object')

# %%
pdhtml[1].columns
# Out:
# Index(['Franchise', 'Lg', 'From', 'To', 'Yrs', 'Season', 'Career'], dtype='object')

# %%
pdhtml[0].dtypes
# Out:
# Franchise    object
# Lg           object
# From         object
# To           object
# Yrs           int64
# Season       object
# Career       object
# dtype: object

# %%
pdhtml[1].dtypes
# Out:
# Franchise    object
# Lg           object
# From         object
# To           object
# Yrs           int64
# Season       object
# Career       object
# dtype: object

# %%
pdhtml[0].describe()
# Out:
#              Yrs
# count  85.000000
# mean   31.352941
# std    25.022707
# min     1.000000
# 25%     9.000000
# 50%    28.000000
# 75%    55.000000
# max    77.000000

# %%
pdhtml[0].to_csv("player.csv",index=False)

# %%
csv=pd.read_csv("player.csv")

# %%
csv
# Out:
#                 Franchise   Lg     From       To  Yrs          Season  \
# 0           Atlanta Hawks  NBA  1949-50  2022-23   74  Season Leaders
# 1           Atlanta Hawks  NBA  1968-69  2022-23   55             NaN
# 2         St. Louis Hawks  NBA  1955-56  1967-68   13             NaN
# 3         Milwaukee Hawks  NBA  1951-52  1954-55    4             NaN
# 4   Tri-Cities Blackhawks  NBA  1949-50  1950-51    2             NaN
# ..                    ...  ...      ...      ...  ...             ...
# 80     Washington Bullets  NBA  1974-75  1996-97   23             NaN
# 81        Capital Bullets  NBA  1973-74  1973-74    1             NaN
# 82      Baltimore Bullets  NBA  1963-64  1972-73   10             NaN
# 83        Chicago Zephyrs  NBA  1962-63  1962-63    1             NaN
# 84        Chicago Packers  NBA  1961-62  1961-62    1             NaN
#
#             Career
# 0   Career Leaders
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...

# %%
csv.head()
# Out:
#                Franchise   Lg     From       To  Yrs          Season  \
# 0          Atlanta Hawks  NBA  1949-50  2022-23   74  Season Leaders
# 1          Atlanta Hawks  NBA  1968-69  2022-23   55             NaN
# 2        St. Louis Hawks  NBA  1955-56  1967-68   13             NaN
# 3        Milwaukee Hawks  NBA  1951-52  1954-55    4             NaN
# 4  Tri-Cities Blackhawks  NBA  1949-50  1950-51    2             NaN
#
#            Career
# 0  Career Leaders
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
csv.tail()
# Out:
#              Franchise   Lg     From       To  Yrs Season Career
# 80  Washington Bullets  NBA  1974-75  1996-97   23    NaN    NaN
# 81     Capital Bullets  NBA  1973-74  1973-74    1    NaN    NaN
# 82   Baltimore Bullets  NBA  1963-64  1972-73   10    NaN    NaN
# 83     Chicago Zephyrs  NBA  1962-63  1962-63    1    NaN    NaN
# 84     Chicago Packers  NBA  1961-62  1961-62    1    NaN    NaN

# %%
csv.head(10)
# Out:
#                Franchise       Lg     From       To  Yrs          Season  \
# 0          Atlanta Hawks      NBA  1949-50  2022-23   74  Season Leaders
# 1          Atlanta Hawks      NBA  1968-69  2022-23   55             NaN
# 2        St. Louis Hawks      NBA  1955-56  1967-68   13             NaN
# 3        Milwaukee Hawks      NBA  1951-52  1954-55    4             NaN
# 4  Tri-Cities Blackhawks      NBA  1949-50  1950-51    2             NaN
# 5         Boston Celtics  NBA/BAA  1946-47  2022-23   77  Season Leaders
# 6          Brooklyn Nets  NBA/ABA  1967-68  2022-23   56  Season Leaders
# 7          Brooklyn Nets      NBA  2012-13  2022-23   11             NaN
# 8        New Jersey Nets      NBA  1977-78  2011-12   35             NaN
# 9          New York Nets      NBA  1976-77  1976-77    1             NaN
#
#            Career
# 0  Career Leaders
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5  Career Leaders
# 6  Career Leaders
# ...

# %%
csv.tail(10)
# Out:
#              Franchise   Lg     From       To  Yrs          Season  \
# 75           Utah Jazz  NBA  1974-75  2022-23   49  Season Leaders
# 76           Utah Jazz  NBA  1979-80  2022-23   44             NaN
# 77    New Orleans Jazz  NBA  1974-75  1978-79    5             NaN
# 78  Washington Wizards  NBA  1961-62  2022-23   62  Season Leaders
# 79  Washington Wizards  NBA  1997-98  2022-23   26             NaN
# 80  Washington Bullets  NBA  1974-75  1996-97   23             NaN
# 81     Capital Bullets  NBA  1973-74  1973-74    1             NaN
# 82   Baltimore Bullets  NBA  1963-64  1972-73   10             NaN
# 83     Chicago Zephyrs  NBA  1962-63  1962-63    1             NaN
# 84     Chicago Packers  NBA  1961-62  1961-62    1             NaN
#
#             Career
# 75  Career Leaders
# 76             NaN
# 77             NaN
# 78  Career Leaders
# 79             NaN
# 80             NaN
# 81             NaN
# 82             NaN
# 83             NaN
# 84             NaN

# %%
csv.describe()
# Out:
#              Yrs
# count  85.000000
# mean   31.352941
# std    25.022707
# min     1.000000
# 25%     9.000000
# 50%    28.000000
# 75%    55.000000
# max    77.000000

# %%
csv.columns
# Out:
# Index(['Franchise', 'Lg', 'From', 'To', 'Yrs', 'Season', 'Career'], dtype='object')

# %%
a=csv[["Franchise"]]

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
b=csv["To"]

# %%
type(b)
# Out:
# pandas.core.series.Series

# %%
csv[['Lg', 'From', 'To', 'Yrs']]
# Out:
#      Lg     From       To  Yrs
# 0   NBA  1949-50  2022-23   74
# 1   NBA  1968-69  2022-23   55
# 2   NBA  1955-56  1967-68   13
# 3   NBA  1951-52  1954-55    4
# 4   NBA  1949-50  1950-51    2
# ..  ...      ...      ...  ...
# 80  NBA  1974-75  1996-97   23
# 81  NBA  1973-74  1973-74    1
# 82  NBA  1963-64  1972-73   10
# 83  NBA  1962-63  1962-63    1
# 84  NBA  1961-62  1961-62    1
#
# [85 rows x 4 columns]

# %%
csv.dtypes
# Out:
# Franchise    object
# Lg           object
# From         object
# To           object
# Yrs           int64
# Season       object
# Career       object
# dtype: object

# %%
[csv.dtypes==int64].index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 [csv.dtypes==int64].index
#
# NameError: name 'int64' is not defined

# %%
csv["cap"]=0

# %%
csv
# Out:
#                 Franchise   Lg     From       To  Yrs          Season  \
# 0           Atlanta Hawks  NBA  1949-50  2022-23   74  Season Leaders
# 1           Atlanta Hawks  NBA  1968-69  2022-23   55             NaN
# 2         St. Louis Hawks  NBA  1955-56  1967-68   13             NaN
# 3         Milwaukee Hawks  NBA  1951-52  1954-55    4             NaN
# 4   Tri-Cities Blackhawks  NBA  1949-50  1950-51    2             NaN
# ..                    ...  ...      ...      ...  ...             ...
# 80     Washington Bullets  NBA  1974-75  1996-97   23             NaN
# 81        Capital Bullets  NBA  1973-74  1973-74    1             NaN
# 82      Baltimore Bullets  NBA  1963-64  1972-73   10             NaN
# 83        Chicago Zephyrs  NBA  1962-63  1962-63    1             NaN
# 84        Chicago Packers  NBA  1961-62  1961-62    1             NaN
#
#             Career  cap
# 0   Career Leaders    0
# 1              NaN    0
# 2              NaN    0
# 3              NaN    0
# ...
