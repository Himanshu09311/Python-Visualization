# %%
import pandas as pd
import seaborn as sns
import lxml

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv("player.csv")

# %%
df
# Out:
#                 Franchise   Lg     From       To  Yrs          Season  \
# 0           Atlanta Hawks  NBA  1949-50  2022-23   74  Season Leaders
# 1           Atlanta Hawks  NBA  1968-69  2022-23   55             NaN
# 2         St. Louis Hawks  NBA  1955-56  1967-68   13             NaN
# 3         Milwaukee Hawks  NBA  1951-52  1954-55    4             NaN
# 4   Tri-Cities Blackhawks  NBA  1949-50  1950-51    2             NaN
# ..                    ...  ...      ...      ...  ...             ...
# 80     Washington Bullets  NBA  1974-75  1996-97   23             NaN
# 81        Capital Bullets  NBA  1973-74  1973-74    1             NaN
# 82      Baltimore Bullets  NBA  1963-64  1972-73   10             NaN
# 83        Chicago Zephyrs  NBA  1962-63  1962-63    1             NaN
# 84        Chicago Packers  NBA  1961-62  1961-62    1             NaN
#
#             Career
# 0   Career Leaders
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...

# %%
s1=sns.load_dataset("titanic")

# %%
s1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
s1.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
s1.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
s1.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
s1.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
s1.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
s1.tail(6)
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked   class  \
# 885         0       3  female  39.0      0      5  29.125        Q   Third
# 886         0       2    male  27.0      0      0  13.000        S  Second
# 887         1       1  female  19.0      0      0  30.000        S   First
# 888         0       3  female   NaN      1      2  23.450        S   Third
# 889         1       1    male  26.0      0      0  30.000        C   First
# 890         0       3    male  32.0      0      0   7.750        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 885  woman       False  NaN   Queenstown    no  False
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
type(s1)
# Out:
# pandas.core.frame.DataFrame

# %%
s1["pclass"]
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
type(s1["pclass"])
# Out:
# pandas.core.series.Series

# %%
s1[["pclass","embarked","class","who","adult_male"]]
# Out:
#      pclass embarked   class    who  adult_male
# 0         3        S   Third    man        True
# 1         1        C   First  woman       False
# 2         3        S   Third  woman       False
# 3         1        S   First  woman       False
# 4         3        S   Third    man        True
# ..      ...      ...     ...    ...         ...
# 886       2        S  Second    man        True
# 887       1        S   First  woman       False
# 888       3        S   Third  woman       False
# 889       1        C   First    man        True
# 890       3        Q   Third    man        True
#
# [891 rows x 5 columns]

# %%
type(s1[["pclass","embarked","class","who","adult_male"]])
# Out:
# pandas.core.frame.DataFrame

# %%
s1.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# pd.read_excel("abcd.xlsx")

# %%
s2=pd.read_html("https://www.basketball-reference.com/draft/NBA_2022.html")

# %%
len(s2)
# Out:
# 1

# %%
type(s2)
# Out:
# list

# %%
data1=s2[0]

# %% [markdown]
# store data

# %%
data1.to_csv("basketball.csv")

# %%
data1
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0           Round 1  \
#                    Rk                 Pk                 Tm            Player
# 0                   1                  1                ORL    Paolo Banchero
# 1                   2                  2                OKC     Chet Holmgren
# 2                   3                  3                HOU  Jabari Smith Jr.
# 3                   4                  4                SAC     Keegan Murray
# 4                   5                  5                DET        Jaden Ivey
# ..                ...                ...                ...               ...
# 57                 56                 56                CLE      Luke Travers
# 58                 57                 57                POR     Jabari Walker
# 59                 58                 58                IND       Hugo Besson
# 60                NaN                NaN                NaN               NaN
# ...

# %%
bs=pd.read_csv("basketball.csv")

# %%
bs
# Out:
#     Unnamed: 0 Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
# 0          NaN                 Rk                 Pk                 Tm
# 1          0.0                  1                  1                ORL
# 2          1.0                  2                  2                OKC
# 3          2.0                  3                  3                HOU
# 4          3.0                  4                  4                SAC
# ..         ...                ...                ...                ...
# 58        57.0                 56                 56                CLE
# 59        58.0                 57                 57                POR
# 60        59.0                 58                 58                IND
# 61        60.0                NaN                NaN                NaN
# 62        61.0                NaN                NaN                NaN
#
#              Round 1 Round 1.1  \
# 0             Player   College
# 1     Paolo Banchero      Duke
# ...

# %%
bs.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0_level_0', 'Unnamed: 1_level_0',
#        'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0',
#        'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting',
#        'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2',
#        'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3'],
#       dtype='object')

# %%
bs.dtypes
# Out:
# Unnamed: 0            float64
# Unnamed: 0_level_0     object
# Unnamed: 1_level_0     object
# Unnamed: 2_level_0     object
# Round 1                object
# Round 1.1              object
# Unnamed: 5_level_0     object
# Totals                 object
# Totals.1               object
# Totals.2               object
# Totals.3               object
# Totals.4               object
# Shooting               object
# Shooting.1             object
# Shooting.2             object
# Per Game               object
# Per Game.1             object
# Per Game.2             object
# Per Game.3             object
# Advanced               object
# Advanced.1             object
# Advanced.2             object
# Advanced.3             object
# dtype: object

# %% [markdown]
# Describe

# %%
bs.describe()
# Out:
#        Unnamed: 0
# count   62.000000
# mean    30.500000
# std     18.041619
# min      0.000000
# 25%     15.250000
# 50%     30.500000
# 75%     45.750000
# max     61.000000

# %% [markdown]
# Head and Tail

# %%
bs.head()
# Out:
#    Unnamed: 0 Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
# 0         NaN                 Rk                 Pk                 Tm
# 1         0.0                  1                  1                ORL
# 2         1.0                  2                  2                OKC
# 3         2.0                  3                  3                HOU
# 4         3.0                  4                  4                SAC
#
#             Round 1 Round 1.1 Unnamed: 5_level_0 Totals Totals.1 Totals.2  \
# 0            Player   College                Yrs      G       MP      PTS
# 1    Paolo Banchero      Duke                  1     59     1987     1178
# 2     Chet Holmgren   Gonzaga                NaN    NaN      NaN      NaN
# 3  Jabari Smith Jr.    Auburn                  1     62     1857      732
# 4     Keegan Murray      Iowa                  1     62     1850      738
#
#    ... Shooting.1 Shooting.2 Per Game Per Game.1 Per Game.2 Per Game.3  \
# ...

# %%
bs.tail()
# Out:
#     Unnamed: 0 Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
# 58        57.0                 56                 56                CLE
# 59        58.0                 57                 57                POR
# 60        59.0                 58                 58                IND
# 61        60.0                NaN                NaN                NaN
# 62        61.0                NaN                NaN                NaN
#
#           Round 1 Round 1.1  \
# 58   Luke Travers       NaN
# 59  Jabari Walker  Colorado
# 60    Hugo Besson       NaN
# 61            NaN       NaN
# 62            NaN       NaN
#
#                                    Unnamed: 5_level_0  \
# 58                                                NaN
# 59                                                  1
# 60                                                NaN
# 61  Milwaukee Bucks forfeited their Second Round p...
# 62      Miami Heat forfeited their Second Round pick.
#
# ...

# %% [markdown]
# slicing

# %%
bs[["Totals","Totals.1","Totals.2"]][2:10]
# Out:
#   Totals Totals.1 Totals.2
# 2    NaN      NaN      NaN
# 3     62     1857      732
# 4     62     1850      738
# 5     61     1841      940
# 6     66     1857     1114
# 7     64     1307      502
# 8     43      818      181
# 9     52     1362      550

# %%
bs[["Totals","Totals.1","Totals.2"]][2:50:4]
# Out:
#    Totals Totals.1 Totals.2
# 2     NaN      NaN      NaN
# 6      66     1857     1114
# 10     13       62       16
# 14     43      714      232
# 18     26      128       46
# 22     62     1365      521
# 26     25      144       38
# 30     14       44       22
# 34     38      600      153
# 38    NaN      NaN      NaN
# 42     31      456      117
# 46     12       62       23

# %% [markdown]
# add coloumns

# %%
s1["royal"]=0

# %%
s1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
s1["category"]=s1["survived"]+s1["pclass"]

# %%
s1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# categorical

# %%
pd.Categorical(s1["embarked"])
# Out:
# ['S', 'C', 'S', 'S', 'S', ..., 'S', 'S', 'S', 'C', 'Q']
# Length: 891
# Categories (3, object): ['C', 'Q', 'S']

# %%
pd.Categorical(s1["sex"])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
s1["pclass"].unique()
# Out:
# array([3, 1, 2])

# %% [markdown]
# condition apply

# %%
s1["age"]>18
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: age, Length: 891, dtype: bool

# %%
s1[s1["age"]>18]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
len(s1[s1["age"]>18])
# Out:
# 575

# %%
(s1[s1["sex"]=="male"])
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  royal  category
# ...

# %%
(s1[s1["sex"]=="female"])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
# ...

# %%
s1[(s1["age"]>20) & (s1["age"]<50)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
min(s1["age"])
# Out:
# 0.42

# %%
max(s1["age"])
# Out:
# 80.0

# %%
s1[10:15]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
# 12         0       3    male  20.0      0      0   8.0500        S  Third
# 13         0       3    male  39.0      1      5  31.2750        S  Third
# 14         0       3  female  14.0      0      0   7.8542        S  Third
#
#       who  adult_male deck  embark_town alive  alone  royal  category
# 10  child       False    G  Southampton   yes  False      0         4
# 11  woman       False    C  Southampton   yes   True      0         2
# 12    man        True  NaN  Southampton    no   True      0         3
# 13    man        True  NaN  Southampton    no  False      0         3
# 14  child       False  NaN  Southampton    no   True      0         3

# %%
s1[["survived","pclass","sex"]][10:15]
# Out:
#     survived  pclass     sex
# 10         1       3  female
# 11         1       1  female
# 12         0       3    male
# 13         0       3    male
# 14         0       3  female

# %% [markdown]
# Iloc and loc

# %% [markdown]
# columns name is indexing

# %%
s1.iloc[0:3,[1,2,3]]
# Out:
#    pclass     sex   age
# 0       3    male  22.0
# 1       1  female  38.0
# 2       3  female  26.0

# %% [markdown]
# columns name is describe

# %%
s1.loc[5:20,["age","class","who"	,"adult_male"]]
# Out:
#      age   class    who  adult_male
# 5    NaN   Third    man        True
# 6   54.0   First    man        True
# 7    2.0   Third  child       False
# 8   27.0   Third  woman       False
# 9   14.0  Second  child       False
# 10   4.0   Third  child       False
# 11  58.0   First  woman       False
# 12  20.0   Third    man        True
# 13  39.0   Third    man        True
# 14  14.0   Third  child       False
# 15  55.0  Second  woman       False
# 16   2.0   Third  child       False
# 17   NaN  Second    man        True
# 18  31.0   Third  woman       False
# 19   NaN   Third  woman       False
# 20  35.0  Second    man        True

# %% [markdown]
# work index

# %%
#Example1

# %%
a=s1["age"][0:5]
b=["a","b","c","d","e"]
c=pd.Series(list(a),index= l)
d=s.append(c)
# Out:
# /tmp/ipykernel_1449/1753885244.py:4: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   d=s.append(c)

# %%
d
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# a    22.0
# b    38.0
# c    26.0
# d    35.0
# e    35.0
# dtype: float64

# %% [markdown]
# slicing is work  indexing in not show

# %%
d[0:6]
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# a    22.0
# dtype: float64

# %% [markdown]
# check single index is always show

# %%
d["a"]
# Out:
# 22.0

# %% [markdown]
# d[6] this is genterate a error

# %%
d[0]
# Out:
# 22.0

# %%
a=pd.Series([11,12,13,14,15,16],index=[0,1,2,3,4,5])
b=pd.Series([11,12,13,14,155,16],index=[5,4,3,2,1,0])
c=a.append(b)
# Out:
# /tmp/ipykernel_1449/3284842073.py:3: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c=a.append(b)

# %%
c
# Out:
# 0     11
# 1     12
# 2     13
# 3     14
# 4     15
# 5     16
# 5     11
# 4     12
# 3     13
# 2     14
# 1    155
# 0     16
# dtype: int64

# %% [markdown]
# check single index is always show and same index value print

# %%
c[0]
# Out:
# 0    11
# 0    16
# dtype: int64

# %% [markdown]
# slicing is work indexing in not show

# %%
c[0:8]
# Out:
# /tmp/ipykernel_1449/1200421676.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   c[0:8]
# 0    11
# 1    12
# 2    13
# 3    14
# 4    15
# 5    16
# 5    11
# 4    12
# dtype: int64

# %% [markdown]
# work in index multplication and adition same index  to add values  and many operation

# %%
a+b
# Out:
# 0     27
# 1    167
# 2     27
# 3     27
# 4     27
# 5     27
# dtype: int64

# %%
a*b
# Out:
# 0     176
# 1    1860
# 2     182
# 3     182
# 4     180
# 5     176
# dtype: int64

# %% [markdown]
# pandas advance

# %%
dt=sns.load_dataset("titanic")

# %%
dt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...
